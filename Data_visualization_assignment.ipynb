# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
from sklearn import datasets
import pandas as pd

# %%
# %matplotlib notebook

# %%
iris=datasets.load_iris()

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
pca=PCA(n_components=3)

# %%
x_reduced=pca.fit_transform(iris.data)

# %%
x_reduced.shape
# Out:
# (150, 3)

# %%
fig=plt.figure(1,figsize=(8,6,))
ax=Axes3D(fig)
scatter=ax.scatter(x_reduced[:,0],x_reduced[:,1],x_reduced[:,2],c=iris.target,marker="o",s=60)
ax.set_title('Transformed_data')
ax.set_xlabel("1st eigenvector")
ax.set_ylabel("2nd eigenvector")
ax.set_zlabel("3rd eigenvector")
legend1 = ax.legend(*scatter.legend_elements(),
                    loc="lower left", title="Classes")
ax.add_artist(legend1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
# C:\Users\DELL\AppData\Local\Temp\ipykernel_31812\774320239.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax=Axes3D(fig)
